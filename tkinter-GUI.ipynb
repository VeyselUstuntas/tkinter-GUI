# %%
from tkinter import *
from tkcalendar import DateEntry

def gonder():
    pass
    return 

master = Tk(className=" Randevu Ekranı") # tkinter sınıfımızdan nesnemizi oluşturduk.

alan = Canvas(master,height = 400, width = 800,bg="#E1ECC8")
alan.pack()

master.minsize(800,400)
master.maxsize(800,400)


alan_ust = Frame(master, bg="#A0C49D")
alan_ust.place(relx=0.0,rely=0.0,relheight=0.20,relwidth=1)


alan_sol = Frame(master,bg="#A0C49D")
alan_sol.place(relx=0.0, rely=0.21,relheight=0.8, relwidth=0.35)

alan_sag_orta = Frame(master,bg="#A0C49D")
alan_sag_orta.place(relx=0.355,rely=0.21,relheight=0.8,relwidth=0.648)

alan_ust_Label = Label(alan_ust,text="Kategori",bg="#F7FFE5",font="Consolas 12 bold")
alan_ust_Label.pack(padx=20,pady=0.1,side=LEFT)

bosluk = StringVar(alan_ust)
bosluk.set("\t\t")
menu = OptionMenu(alan_ust,bosluk,"Göz","Genel Cerrahi","Çocuk","Dahiliye","Kardiyoloji")
menu.pack(padx=20,pady=10, side=LEFT)


tarih_sec = DateEntry(alan_ust,width=20,height=20,background="#F7FFE5",foreground="#A0C49D",font="Consolas 11 bold")
tarih_sec.pack(padx=10,pady=10,side=RIGHT)
tarih = Label(alan_ust,text="Randevu Tarihi",font="Consolas 12 bold",bg="#F7FFE5")
tarih.pack(padx=60,pady=10,side=RIGHT)

Label(alan_sol,text="İşlem Türü",font="Consolas 12 bold",bg="#F7FFE5").pack(padx=10,pady=10,anchor=N,fill=BOTH)


Checkbutton(alan_sol,bg="#A0C49D",text="Randevu AL",font="Consolas 16 bold",foreground="#F7FFE5").pack(padx=10,pady=10,anchor=W)


var=IntVar()
Radiobutton(alan_sol,text="Randevu Degistir",variable = var,value=1,font="Consolas 14 bold",foreground="#F7FFE5",bg="#A0C49D",).pack(padx=10,pady=10,anchor=NW)

Radiobutton(alan_sol,text="Randevu Sil",variable = var,value=2,font="Consolas 14 bold",foreground="#F7FFE5",bg="#A0C49D",).pack(padx=10,pady=10,anchor=NW)

Label(alan_sag_orta,text="Deneme",font="Consolas 12 bold",bg="#F7FFE5").pack(padx=20,pady=10,anchor=NW,fill=BOTH,side=TOP)

bilgi = Text(alan_sag_orta,height=9,width=70,background="#E1ECC8").pack(padx=20,pady=10,anchor=NW)

onay_buton = Button(alan_sag_orta,text="Randevu Al",command=gonder, background="#F7FFE5",font="Consolas 12 bold").pack(padx=10,pady=10,anchor=N)
master.mainloop() # pencerenin sürekli olarak ekranda gözükmesi için kullandı

# %%
from IPython.display import Image
Image(filename='C:\\Users\\veyse\\OneDrive\\Resimler\\Ekran Görüntüleri\\ss.png')
